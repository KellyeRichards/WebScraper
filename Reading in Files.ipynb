# %% [markdown]
# Reading in Files

# %%
import pandas as pd

# This is for structured files like csv, json, excel, structured text, etc.

# %%
df2 = pd.read_csv(r"/Users/kellye/Library/CloudStorage/GoogleDrive-kellye.whitfill@gmail.com/My Drive/WKU - Spring 2024/484 - Systems Security II/Week.csv")

df2
# Out:
#                                              Resource Time In Resource  \
# 0                  4.1.10 Identify Social Engineering              NaN
# 1   4.3.3 Implement Physical Security Countermeasures              NaN
# 2              5.1.7 Perform Reconnaissance with Nmap              NaN
# 3                      5.2.3 Disable Windows Services              NaN
# 4                         5.2.5 Manage Linux Services              NaN
# ..                                                ...              ...
# 67              12.3.7 Evaluate Event Logs in pfSense              NaN
# 68                 12.3.13 Evaluate Windows Log Files              NaN
# 69                         14.2.5 Compare an MD5 Hash              NaN
# 70             14.3.12 Examine a Forensic Drive Image              NaN
# 71                    15.4.6 View Process Information              NaN
#
#    Latest Score Highest Score Lowest Score Average Score  Points Possible  \
# ...

# %%
pd.set_option('display.max.rows', 71)
pd.set_option('display.max.columns', 8)


# /Users/kellye/Library/Group Containers/EQHXZ8M8AV.group.com.google.drivefs/fp/Logs

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Resource          72 non-null     object
#  1   Time In Resource  18 non-null     object
#  2   Latest Score      18 non-null     object
#  3   Highest Score     18 non-null     object
#  4   Lowest Score      18 non-null     object
#  5   Average Score     18 non-null     object
#  6   Points Possible   18 non-null     float64
#  7   Attempts          72 non-null     int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 4.6+ KB

# %%
df2.tail(10)
# Out:
#                                            Resource Time In Resource  \
# 62       12.2.5 Configure Security Appliance Access              NaN
# 63     12.2.8 Evaluate Network Security with Kibana              NaN
# 64   12.2.9 Evaluate Network Security with Hunter-1              NaN
# 65  12.2.10 Evaluate Network Security with Hunter-2              NaN
# 66                   12.3.6 Log Events with pfSense              NaN
# 67            12.3.7 Evaluate Event Logs in pfSense              NaN
# 68               12.3.13 Evaluate Windows Log Files              NaN
# 69                       14.2.5 Compare an MD5 Hash              NaN
# 70           14.3.12 Examine a Forensic Drive Image              NaN
# 71                  15.4.6 View Process Information              NaN
#
#    Latest Score Highest Score Lowest Score Average Score  Points Possible  \
# 62          NaN           NaN          NaN           NaN              NaN
# ...

# %%
df2.head(10)
# Out:
#                                             Resource Time In Resource  \
# 0                 4.1.10 Identify Social Engineering              NaN
# 1  4.3.3 Implement Physical Security Countermeasures              NaN
# 2             5.1.7 Perform Reconnaissance with Nmap              NaN
# 3                     5.2.3 Disable Windows Services              NaN
# 4                        5.2.5 Manage Linux Services              NaN
# 5            5.2.6 Enable and Disable Linux Services              NaN
# 6                5.2.9 Hide the IIS Banner Broadcast              NaN
# 7   5.3.4 Troubleshoot Connectivity with ping/hping3              NaN
# 8           5.3.6 Perform an Internal Scan with Nmap              NaN
# 9        5.3.7 Perform an External Scan Using Zenmap              NaN
#
#   Latest Score Highest Score Lowest Score Average Score  Points Possible  \
# 0          NaN           NaN          NaN           NaN              NaN
# ...

# %%
df2['Resource']
# Out:
# 0                    4.1.10 Identify Social Engineering
# 1     4.3.3 Implement Physical Security Countermeasures
# 2                5.1.7 Perform Reconnaissance with Nmap
# 3                        5.2.3 Disable Windows Services
# 4                           5.2.5 Manage Linux Services
#                             ...
# 67                12.3.7 Evaluate Event Logs in pfSense
# 68                   12.3.13 Evaluate Windows Log Files
# 69                           14.2.5 Compare an MD5 Hash
# 70               14.3.12 Examine a Forensic Drive Image
# 71                      15.4.6 View Process Information
# Name: Resource, Length: 72, dtype: object

# %%
df2.loc[62]
# Out:
# Resource            12.2.5 Configure Security Appliance Access
# Time In Resource                                           NaN
# Latest Score                                               NaN
# Highest Score                                              NaN
# Lowest Score                                               NaN
# Average Score                                              NaN
# Points Possible                                            NaN
# Attempts                                                     0
# Name: 62, dtype: object
